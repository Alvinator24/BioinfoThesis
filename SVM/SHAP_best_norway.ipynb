# %%
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import os
import joblib

# %%
# -----------------------------
# SETTINGS
# -----------------------------
MAX_BACKGROUND = 20       # Background samples for SHAP
MAX_EXPLAIN = 30          # Test samples for SHAP
MAX_FEATURES_FOR_SHAP = 100  # Reduce features to this number
TOP_K = 20                # Top features to show in plots
RANDOM_STATE = 42
OUT_DIR = "./shap_best_norway_results"
os.makedirs(OUT_DIR, exist_ok=True)

# %%
# -----------------------------
# LOAD PIPELINE
# -----------------------------
pipeline = joblib.load("svm_smote_Norway.pkl")
svm_model = pipeline.named_steps['svm']
print(f"SVM kernel: {svm_model.kernel}")
# Out:
# SVM kernel: rbf
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator NearestNeighbors from version 1.8.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator SVC from version 1.8.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
X_train = pd.read_csv('../Datasets/X_train_Norway.csv')
X_test  = pd.read_csv('../Datasets/X_test_Norway.csv')

# %%
# -----------------------------
# PREPARE DATA
# -----------------------------
X_train_arr = X_train.values if hasattr(X_train, "values") else X_train
X_test_arr = X_test.values if hasattr(X_test, "values") else X_test

# %%
# -----------------------------
# FEATURE REDUCTION
# -----------------------------
n_features_total = X_train_arr.shape[1]

if n_features_total > MAX_FEATURES_FOR_SHAP:
    print(f"Reducing features from {n_features_total} to {MAX_FEATURES_FOR_SHAP}")

    # Select top features by variance
    feature_vars = np.var(X_train_arr, axis=0)
    top_indices = np.argsort(feature_vars)[-MAX_FEATURES_FOR_SHAP:]
    top_indices = sorted(top_indices)

    X_train_reduced = X_train_arr[:, top_indices]
    X_test_reduced = X_test_arr[:, top_indices]

    feature_names = X_train.columns[top_indices].tolist() if hasattr(X_train, "columns") else [f"Feature_{i}" for i in top_indices]
else:
    top_indices = np.arange(n_features_total)
    X_train_reduced = X_train_arr
    X_test_reduced = X_test_arr
    feature_names = X_train.columns.tolist() if hasattr(X_train, "columns") else [f"Feature_{i}" for i in range(n_features_total)]

print(f"Using {X_train_reduced.shape[1]} features for SHAP")
# Out:
# Reducing features from 20789 to 100
# Using 100 features for SHAP

# %%
# -----------------------------
# SAMPLE BACKGROUND + TEST
# -----------------------------
def shap_sample(X, n, random_state):
    idx = np.random.RandomState(random_state).choice(len(X), size=n, replace=False)
    return X[idx]

background_reduced = shap_sample(X_train_reduced, min(MAX_BACKGROUND, len(X_train_reduced)), RANDOM_STATE)
X_explain_reduced = shap_sample(X_test_reduced, min(MAX_EXPLAIN, len(X_test_reduced)), RANDOM_STATE)

print("Background shape:", background_reduced.shape)
print("Explain shape:", X_explain_reduced.shape)
# Out:
# Background shape: (20, 100)
# Explain shape: (30, 100)

# %%
# -----------------------------
# MODEL WRAPPER FOR REDUCED FEATURES
# -----------------------------
def model_wrapper(X_reduced):
    """
    Expands X_reduced (selected features) to full feature space
    Non-selected features set to zero
    """
    batch_size = X_reduced.shape[0]
    X_full = np.zeros((batch_size, X_train_arr.shape[1]))
    X_full[:, top_indices] = X_reduced
    return pipeline.predict_proba(X_full)

# %%
# -----------------------------
# INITIALIZE SHAP EXPLAINER
# -----------------------------
print("\nInitializing SHAP Explainer...")
explainer = shap.Explainer(model_wrapper, background_reduced)

# Compute SHAP values
shap_values = explainer(X_explain_reduced)
gc.collect()
print("SHAP values computed successfully")
# Out:
# Initializing SHAP Explainer...
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:   3%|▎         | 1/30 [00:00<?, ?it/s]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  10%|█         | 3/30 [08:54<1:07:12, 149.34s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  13%|█▎        | 4/30 [14:03<1:33:39, 216.12s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  17%|█▋        | 5/30 [19:23<1:46:10, 254.81s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  20%|██        | 6/30 [23:48<1:43:24, 258.52s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  23%|██▎       | 7/30 [26:57<1:30:14, 235.43s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  27%|██▋       | 8/30 [32:21<1:36:42, 263.76s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  30%|███       | 9/30 [37:54<1:39:54, 285.44s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  33%|███▎      | 10/30 [43:06<1:37:58, 293.93s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  37%|███▋      | 11/30 [46:45<1:25:45, 270.83s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  40%|████      | 12/30 [51:04<1:20:09, 267.20s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  43%|████▎     | 13/30 [54:09<1:08:37, 242.18s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  47%|████▋     | 14/30 [57:15<1:00:06, 225.38s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  50%|█████     | 15/30 [1:00:33<54:13, 216.91s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  53%|█████▎    | 16/30 [1:04:16<51:05, 218.96s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  57%|█████▋    | 17/30 [1:07:24<45:23, 209.52s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  60%|██████    | 18/30 [1:10:31<40:31, 202.63s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  63%|██████▎   | 19/30 [1:13:44<36:38, 199.88s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  67%|██████▋   | 20/30 [1:17:04<33:18, 199.85s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  70%|███████   | 21/30 [1:21:55<34:06, 227.43s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  73%|███████▎  | 22/30 [1:32:31<46:40, 350.06s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  77%|███████▋  | 23/30 [1:41:39<47:45, 409.33s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  80%|████████  | 24/30 [1:50:11<44:01, 440.22s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  83%|████████▎ | 25/30 [1:59:49<40:07, 481.55s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  87%|████████▋ | 26/30 [2:08:20<32:41, 490.38s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  90%|█████████ | 27/30 [2:17:15<25:11, 503.69s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  93%|█████████▎| 28/30 [2:26:15<17:09, 514.51s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer:  97%|█████████▋| 29/30 [2:33:37<08:12, 492.71s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer: 100%|██████████| 30/30 [2:38:56<00:00, 440.65s/it]c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# PermutationExplainer explainer: 31it [2:42:02, 324.09s/it]
# SHAP values computed successfully

# %%
# -----------------------------
# PROCESS SHAP VALUES
# -----------------------------
if isinstance(shap_values.values, list):
    shap_arr = np.stack([np.array(s) for s in shap_values.values], axis=2)  # (samples, features, classes)
else:
    shap_arr = np.array(shap_values.values)

print(f"SHAP values shape: {shap_arr.shape}")
# Out:
# SHAP values shape: (30, 100, 5)

# %%
# -----------------------------
# OVERALL FEATURE IMPORTANCE
# -----------------------------
if shap_arr.ndim == 3:
    shap_overall = np.abs(shap_arr).max(axis=2)
else:
    shap_overall = np.abs(shap_arr)

mean_abs_shap = shap_overall.mean(axis=0)

df_shap = pd.DataFrame({
    "Feature": feature_names,
    "MeanAbsSHAP": mean_abs_shap
}).sort_values(by="MeanAbsSHAP", ascending=False)

df_shap.head(TOP_K).to_csv(os.path.join(OUT_DIR, "top_features_overall.csv"), index=False)

# Plot top features
plt.figure(figsize=(10, 8))
sns.barplot(data=df_shap.head(TOP_K), x="MeanAbsSHAP", y="Feature", palette="viridis")
plt.title(f"Top {TOP_K} Features by Mean |SHAP|")
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "top_features_bar.png"), dpi=150)
plt.close()
# Out:
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_25816\1859592440.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_shap.head(TOP_K), x="MeanAbsSHAP", y="Feature", palette="viridis")

# %%
# -----------------------------
# PER-CLASS SUMMARY PLOTS (if multi-class)
# -----------------------------
if shap_arr.ndim == 3:
    n_classes = shap_arr.shape[2]
    classes = pipeline.named_steps['svm'].classes_
    for class_idx in range(n_classes):
        class_label = classes[class_idx]
        class_shap = shap_arr[:, :, class_idx]
        plt.figure(figsize=(12, 10))
        shap.summary_plot(class_shap, X_explain_reduced, feature_names=feature_names, max_display=TOP_K, show=False)
        plt.title(f"SHAP Summary - {class_label}")
        plt.tight_layout()
        plt.savefig(os.path.join(OUT_DIR, f"shap_summary_{class_label}.png"), dpi=150)
        plt.close()

print(f"\nSHAP analysis complete. Results saved to: {OUT_DIR}")
# Out:
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_25816\3814199151.py:11: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(class_shap, X_explain_reduced, feature_names=feature_names, max_display=TOP_K, show=False)
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_25816\3814199151.py:11: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(class_shap, X_explain_reduced, feature_names=feature_names, max_display=TOP_K, show=False)
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_25816\3814199151.py:11: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(class_shap, X_explain_reduced, feature_names=feature_names, max_display=TOP_K, show=False)
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_25816\3814199151.py:11: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(class_shap, X_explain_reduced, feature_names=feature_names, max_display=TOP_K, show=False)
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_25816\3814199151.py:11: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(class_shap, X_explain_reduced, feature_names=feature_names, max_display=TOP_K, show=False)
# SHAP analysis complete. Results saved to: ./shap_best_norway_results

# %%
# -----------------------------
# COMBINED SHAP SUMMARY (ALL CLASSES)
# -----------------------------
print("\n[SHAP] Generating combined SHAP summary plot...")

if shap_arr.ndim == 3:
    shap_combined = np.mean(np.abs(shap_arr), axis=2)
else:
    shap_combined = np.abs(shap_arr)

plt.figure(figsize=(14, 10))
shap.summary_plot(
    shap_combined,
    X_explain_reduced,
    feature_names=feature_names,
    max_display=TOP_K,
    show=False
)

plt.title("Overall SHAP Summary")
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "overall_shap_summary.png"), dpi=150)
plt.close()

print("Combined SHAP summary saved.")
# Out:
# [SHAP] Generating combined SHAP summary plot...
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_25816\116974704.py:12: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# Combined SHAP summary saved.
